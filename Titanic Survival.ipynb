# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
#import the dataset
df = pd.read_csv("D:\\power bi\\dataset\\archive_1\\tested.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
#description of the features
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
#information of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
#shape of dataset
df.shape
# Out:
# (418, 12)

# %%
#checking the null values 
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
#moving the column Survived at the end
df["Survived_1"] = df["Survived"]
df=df.drop("Survived",axis=1)

# %%
df=df.rename(columns={"Survived_1":"Survived"})

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# Survived         0
# dtype: int64

# %% [markdown]
# ## Data Preprocessing

# %%
#average impution of the null values on columns "Age" and "Fare"
df.fillna({"Age":30.2,"Fare":35.6271},inplace=True)

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          327
# Embarked         0
# Survived         0
# dtype: int64

# %%
#dropping the column "Cabin" as 327 values are missing
df = df.drop("Cabin",axis=1)

# %%
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Embarked  Survived
# 0  34.5      0      0   330911   7.8292        Q         0
# 1  47.0      1      0   363272   7.0000        S         1
# 2  62.0      0      0   240276   9.6875        Q         0
# 3  27.0      0      0   315154   8.6625        S         0
# 4  22.0      1      1  3101298  12.2875        S         1

# %%
#unique values of embarked column
df["Embarked"].unique()
# Out:
# array(['Q', 'S', 'C'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          418 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         418 non-null    float64
#  9   Embarked     418 non-null    object
#  10  Survived     418 non-null    int64
# dtypes: float64(2), int64(5), object(4)
# memory usage: 36.0+ KB

# %% [markdown]
# ## Data Visualization

# %%
fig,ax = plt.subplots()
sns.set_theme(style="darkgrid")
plt.xticks(rotation=90)
plt.title("Count of people survived/not survived")
ax = sns.countplot(x="Survived",data=df)

# %%
plt.title("Count of male and female")
sns.countplot(x="Sex",data=df)
# Out:
# <Axes: title={'center': 'Count of male and female'}, xlabel='Sex', ylabel='count'>

# %%
plt.title("Count of people survived as per Pclass")
sns.countplot(data=df,x="Survived",hue="Pclass")
# Out:
# <Axes: title={'center': 'Count of people survived as per Pclass'}, xlabel='Survived', ylabel='count'>

# %%
plt.title("Count of Age of passengers")
sns.histplot(df,x="Age")
# Out:
# <Axes: title={'center': 'Count of Age of passengers'}, xlabel='Age', ylabel='Count'>

# %%
plt.title("Count of people survived as per SibSp")
sns.countplot(data=df,x="SibSp")
# Out:
# <Axes: title={'center': 'Count of people survived as per SibSp'}, xlabel='SibSp', ylabel='count'>

# %%
sns.pairplot(df,hue="Sex")

# %% [markdown]
# ### Encoding categorical features

# %%
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder(sparse=False,handle_unknown="ignore")
df_encoded = pd.DataFrame(encoder.fit_transform(df[["Sex","Embarked"]]),
                          columns=encoder.get_feature_names_out(["Sex","Embarked"]))
df.drop(columns=["Sex","Embarked"],inplace=True)
df = pd.concat([df,df_encoded],axis=1)
df.head()
# Out:
#    PassengerId  Pclass                                          Name   Age  \
# 0          892       3                              Kelly, Mr. James  34.5
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  47.0
# 2          894       2                     Myles, Mr. Thomas Francis  62.0
# 3          895       3                              Wirz, Mr. Albert  27.0
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  22.0
#
#    SibSp  Parch   Ticket     Fare  Survived  Sex_female  Sex_male  Embarked_C  \
# 0      0      0   330911   7.8292         0         0.0       1.0         0.0
# 1      1      0   363272   7.0000         1         1.0       0.0         0.0
# 2      0      0   240276   9.6875         0         0.0       1.0         0.0
# 3      0      0   315154   8.6625         0         0.0       1.0         0.0
# 4      1      1  3101298  12.2875         1         1.0       0.0         0.0
#
#    Embarked_Q  Embarked_S
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Age          418 non-null    float64
#  4   SibSp        418 non-null    int64
#  5   Parch        418 non-null    int64
#  6   Ticket       418 non-null    object
#  7   Fare         418 non-null    float64
#  8   Survived     418 non-null    int64
#  9   Sex_female   418 non-null    float64
#  10  Sex_male     418 non-null    float64
#  11  Embarked_C   418 non-null    float64
#  12  Embarked_Q   418 non-null    float64
#  13  Embarked_S   418 non-null    float64
# dtypes: float64(7), int64(5), object(2)
# memory usage: 45.8+ KB

# %%
df=df.drop("Name",axis=1)

# %%
df = df.drop("Ticket",axis=1)

# %%
df.shape
# Out:
# (418, 12)

# %% [markdown]
# ## Model training and prediction

# %%
X = df.drop("Survived",axis=1)
y = df["Survived"]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2)

# %% [markdown]
# ### Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier()

# %%
clf.fit(X_train,y_train);

# %%
y_preds = clf.predict(X_test)

# %%
clf.score(X_test,y_test) # achieving 100% accuracy
# Out:
# 1.0

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        54
#            1       1.00      1.00      1.00        30
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(max_iter=1000)
model.fit(X_train,y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
preds = model.predict(X_test)

# %%
model.score(X_test,y_test) #achieving 100% accuracy
# Out:
# 1.0

# %%
print(classification_report(y_test,preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        54
#            1       1.00      1.00      1.00        30
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
